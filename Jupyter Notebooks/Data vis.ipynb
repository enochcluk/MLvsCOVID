# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn as sk

import sys
import datetime as datetime
from datetime import datetime as dt
from datetime import timedelta as td
from datetime import date as dater

df = pd.read_csv(r'C:/Users/enoch/Desktop/MLvsCOVID/completedataset.csv')
df=df.set_index(['county','date'])
#print(df)

# %%
def adddelaycolumn():
    relevantdate = df.index.tolist() 
    bchanges =[]

    for item in relevantdate:
        thing = df.loc[item]
        percentnew = thing['new_confirmed_cases']/(thing['confirmed_cases']+0.0001)
    
        bchanges.append(percentnew)
    
    df['percentnew']=bchanges

adddelaycolumn()   
print
# Out:
# <function print>

# %%
pd.set_option("display.max_rows", 20, "display.max_columns", None)

print (df)
# Out:
#                     retailandrec  groceryandpharm  parks  transit  work  \
# county  date
# Alameda 2020-02-20           1.0              1.0   13.0      2.0   0.0
#         2020-02-21           1.0              1.0    8.0     -1.0   3.0
#         2020-02-26           2.0              2.0   20.0      3.0   2.0
#         2020-02-28           3.0              5.0    8.0      0.0   4.0
#         2020-02-29           2.0              7.0   14.0     -4.0   3.0
# ...                          ...              ...    ...      ...   ...
# Yuba    2020-07-13         -13.0              8.0    NaN     -9.0 -32.0
#         2020-07-14          -9.0              8.0    NaN     -8.0 -31.0
#         2020-07-15          -9.0              9.0    NaN    -14.0 -34.0
#         2020-07-16         -12.0             18.0    NaN    -12.0 -33.0
#         2020-07-17         -13.0              9.0    NaN    -17.0 -34.0
#
#                     residential  confirmed_cases  deaths  new_confirmed_cases  \
# county  date
# Alameda 2020-02-20          0.0                0       0                  0.0
#         2020-02-21          0.0                0       0                  0.0
#         2020-02-26         -1.0                0       0                  0.0
#         2020-02-28          0.0                0       0                  0.0
#         2020-02-29         -1.0                0       0                  0.0
# ...                         ...              ...     ...                  ...
# Yuba    2020-07-13          6.0              211       3                 13.0
#         2020-07-14          7.0              221       3                 10.0
#         2020-07-15          7.0              231       3                 10.0
#         2020-07-16          7.0              236       3                  5.0
#         2020-07-17          8.0              252       3                 16.0
#
#                     new_deaths  percentnew
# county  date
# Alameda 2020-02-20         0.0    0.000000
#         2020-02-21         0.0    0.000000
#         2020-02-26         0.0    0.000000
#         2020-02-28         0.0    0.000000
#         2020-02-29         0.0    0.000000
# ...                        ...         ...
# Yuba    2020-07-13         0.0    0.061611
#         2020-07-14         0.0    0.045249
#         2020-07-15         0.0    0.043290
#         2020-07-16         0.0    0.021186
#         2020-07-17         0.0    0.063492
#
# [7080 rows x 11 columns]

# %%
plt.figure(figsize=(20,10))
la=df.loc['Los Angeles']
#print(la)
sns.lineplot(data=la['retailandrec'],color='red',label='retailandrec')
sns.lineplot(data=la['groceryandpharm'],color='orange')
sns.lineplot(data=la['parks'],color='yellow')
sns.lineplot(data=la['transit'],color='green')
sns.lineplot(data=la['work'],color='blue')
sns.lineplot(data=la['residential'],color='purple')
plt.xticks(rotation=90)
plt.show()

# %%
corr=new_df.corr()
mask = np.zeros(corr.shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True
plt.figure(figsize=(10,10))

thing = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap='rainbow',
    square=True,
    mask=mask
)
thing.set_xticklabels(labels=thing.get_xticklabels(),rotation=80)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e20cfda7c228> in <module>
# ----> 1 corr=new_df.corr()
#       2 mask = np.zeros(corr.shape, dtype=bool)
#       3 mask[np.triu_indices(len(mask))] = True
#       4 plt.figure(figsize=(10,10))
#       5
#
# NameError: name 'new_df' is not defined
